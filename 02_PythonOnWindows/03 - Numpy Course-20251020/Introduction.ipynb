# %% [markdown]
# # NumPy
#
# ## Introduction
#
# NumPy (**Num**erical **Py**thon) is an open source Python library that’s widely used in science and engineering[^1]. For example, you can use it for working with vectors, matrices, linear algebra, optimization and much more. This course gives an overview, but it is intended to be extended by readers with online ressources for an in-depth understanding.
#
# [^1]: <https://numpy.org/devdocs/user/index.html>
#
# ### Course Requirements
#
# This course requires a working Jupyter environment to actively execute the code blocks and solve small programming task and exercises. Basic understanding of Python and its syntax is practical.
#
# ### Course Format
#
# The course is presented as a set of Jupyter notebooks that includes some exercised and taks for self learning.
#
# ### Learning Objectives
#
# After this course you should have learned and be able to:
#
# - run and edit a Jupyter notebook
# - be familiar with NumPy concepts and syntax
# - solve computational science problems in NumPy
# - understand how to work with images in NumPy
#
# ### Outline
#
# Part 1: Data model, ndarray creation and manipulation
#
# Part 2: Indexing, slicing, broadcasting and views
#
# Part 3: Statistics and linear algebra routines
#
# Part 4: Images as ndarrays
