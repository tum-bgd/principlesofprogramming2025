# %%
# %pip install esy-osm-pbf
# Out:
# Collecting esy-osm-pbf
#   Downloading esy_osm_pbf-0.1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting protobuf>=3.20 (from esy-osm-pbf)
#   Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Downloading esy_osm_pbf-0.1.1-py3-none-any.whl (12 kB)
# Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl (436 kB)
# Installing collected packages: protobuf, esy-osm-pbf
#
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 2/2 [esy-osm-pbf]
#
# Successfully installed esy-osm-pbf-0.1.1 protobuf-6.33.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\ge98siw\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import os, urllib.request
import esy.osm.pbf
import os

# %%
if not os.path.exists('andorra.osm.pbf'):
     filename, headers = urllib.request.urlretrieve(
         'https://download.geofabrik.de/europe/andorra-190101.osm.pbf',
         filename='andorra.osm.pbf'
     )

# %%
osm = esy.osm.pbf.File('andorra.osm.pbf')
len([entry for entry in osm if entry.tags.get('leisure') == 'park'])
# Out:
# 21
